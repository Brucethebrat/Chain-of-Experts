# %%
import run_exp
import os
os.environ["OPENAI_API_KEY"] = "your_api_key_here"
# !python run_exp.py --dataset ComplexOR --problem "aircraft_assignment" --algorithm cot
# Out:
# Save log to log\run_cot_ComplexOR_1749848303
# ----------Token usage--------------------
# Tokens Used: 1007
# 	Prompt Tokens: 377
# 		Prompt Tokens Cached: 0
# 	Completion Tokens: 630
# 		Reasoning Tokens: 0
# Successful Requests: 1
# Total Cost (USD): $0.0018255
# -------------------------
# Restricted license - for non-production use only - expires 2026-11-23
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-12700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 11 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0x90e3b26d
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 6e+00]
# Presolve removed 9 rows and 3 columns
# Presolve time: 0.00s
#
# ...
